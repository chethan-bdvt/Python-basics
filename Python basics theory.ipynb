# %%
'''
1.What is Python?Why it is popular?
-->Python is popular programming language.It is so popular because
        • It is easy to understanding/learning, extensive libraries, large and active community developers and open source.
    		• It is compatible with various programming paradigm, such as Procedural, Object    oriented and functional programming.

2.What is Interpreter in Python?
-->An Interpreter in Python is a, Programme that reads and executes the code line by line and translates into machine readable instructions.

3.What are predefined keywords in Python?
--> Predefined keywords are nothing but a keywords that are reserved for Programming in Python,These keywords can not be used as identifiers like variable name,functional name.Keywords are case-sensitive in Python.
        ex: if,else,int,float,None....

4.Can keywords be used as variable names?
--> No,Keywords can not be used as variable names,as each keywords has its own meaning and specific purpose in Python.

5.What is mutability in Python?
--> A Mutability in Python refers whether the value of an object can be changed after it is created.

6.Why lists are mutable and tuples are immutable in Python?
--> In Python lists,Sets and Dictionaries are mutable because, Once after creation of these new elements can be added and existing elements can be modified or delted.While tuples and strings are immutable because in strings a sequence of character can not be changed and in tuple a sequence/order of elements can not be changed.

7.What is the difference between "==" and "is" operator in Python?
-->In Python
   • "==" operator checks for the equality of values,while "is" operator checks for the identity or memory location of two objects.
   • "==" operator returns true if values are same, while "is" operator returns true if memory location of two objects are same.

8.What are logical operator in Python?
--> A logical operators are used for combine or modify boolean expressions evaluate to either true or false.
    "and" Returns true if both operands are true.
    "or" Returns true if one of the operands is true.
    "not" Reverse the result, returns the false if result is true and vice versa.

9.What is type casting in Python?
-->A type conversation in Python is a process of changing one data type to another. It is necessary for performing arithmatic operation, data manipulation  and input/output operation in Python programs.

10.What is implicit and explicit type casting?
--> •An implicit type conversion is process of which the data type converts to another without programmers interventions.
    • An explicit type conversion is process of which the data type converts to another by programmers intervension using built in functions.

11.What is the purpose of conditional statements in Python?
--> A conditional in python are used to execute the code based on outcome of logical expresion such as if, else,esif.

12.How does elif statement work?
--> An elif statement allows to check multiple conditions sequentially. If the initial if condition is false, elif statements are evaluted untill true condition is found and the correspondence block is exicuted.If none of the elif block are true than else block will be executed.

13.What is the difference between for and while loop?
--> "for" loop are used for iterating over a sequence of element. while "while" block is a infinite loop, It will keep on executing until the condition is true.

14. Describe a scenario where a while loop is more suitable than a for loop?
--> A while loop is more suitable when number of iteration is unknown, and loop's continuation depends on a dynamic condition.
'''
