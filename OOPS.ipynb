# %% [markdown]
# OOPS ASSIGNMENT

# %%
'''
1.What is Object-Oriented Programming (OOP)?
  --> An Object-Oriented is a Programming Paradigm that organizes software design around objects rather than function and logic. It aims to model real-world objects, encapsulating data(attributes) and behaviour(methods) into single units.

      Key Concepts of OOP:

        a.Encapsulation: Bundling data and methods that operate on the data within a single unit (class).

        b.Abstraction: Hiding complex implementation details and showing only essential features of an object.

        c.Inheritance: A mechanism where a new class (subclass/derived class) inherits properties and behaviors from an existing class (superclass/base class).

        d.Polymorphism: The ability of an object to take on many forms, allowing objects of different classes to be treated as objects of a common type.
'''

# %%
'''
2.What is a class in OOP?
  -->In OOP, A class is a Blurprint/Template for creating objects. It defines a set of attributes(data) and methods(functions).
'''

# %%
'''
3.What is an object in OOP?
  -->An Object(also known as an Instance) in OOP is a concrete realization of a class. It has it's own unique set of data(attributes) and can perform actions(methods) defined in the class.
'''

# %%
'''
4.What is the difference between abstraction and encapsulation?
  -->Abstraction and Encapsulation are two fundamental concept in OOP.

    Abstraction: Hiding the complex implementation details and showing only essential feature or functionality to an user. It focuses on "WHAT" an object does rather than "HOW".

    Encapsulation: Bundling data(attribute) and the methods(functions) that operates on that data into a single unit(a class). It restricts direct access to some of an objects components, prevents external code from directly manipulating internal state.

'''

# %%
'''
5. What are dunder methods in Python?
  -->Dunder(Double Underscore) methods is also known as magic methods or special methods. These methods are not meant to be called directly by programmers, Instead they are automatically invoked by Python in specific situations or in response to certain built-in operations, syntax or functions.
    ex:  __init__, __str__, __add__.
'''

# %%
'''
6. Explain the concept of inheritance in OOP?
  --> Inherintance in OOP is a concept where a class(usually subclass or derived class or child class) to inherit properties(attributes) and behaviour(methods) from an existing class(called super class, base class, parent class).

'''

# %%
'''
7. What is polymorphism in OOP?
  --> A Polymorphism("many forms") is an OOP principle that allows object of different classes to be treated as object of a common type. It enables a single interface to be used for different underlying data types or classes.

'''

# %%
'''
8. How is encapsulation achieved in Python?
  --> An Encapsulation in OOP is a concept of Bundling data and methods into a single class. We can acheive this using access modifiers.
      Python does not have any strict access modifier like Other languages. Instead it uses a convention to indicate the intended visibility of attributes like underscore(_) which represents the Protected and double underscore(__) represents Private.
''

# %%
'''
9.What is a constructor in Python?
  -->A constructor in Python is a special method that automatically called while object creation. It primary purpose is to Initialize the attributes of the class.
      The constructor is always named with __init__(self). It should not explicitly return any value, implicitly it will return None.

'''

# %%
'''
10.What are class methods and static methods in Python?
  ---> In Python Class methods and Static methods are methods that are bound to a class rather than an instance of the class.

       Class methods:
        a.Defined using @classmethod decorator
        b.Takes cls(the class itself) as it's first arguement.
        c.Can access and modify class-level attributes and call other class methods.
        d.Commonly used for alternative constructor or operations that pertain to the class as a whole.

      Static methods:
        a.Defined using @staticmethod decorator
        b.Takes no special first arguement(self or cls).
        c.Behaves like a regular function defined inside a class. It cannot access instance-specific data or class-specific data directly.

'''

# %%
'''
11. What is method overloading in Python?
  --> Method overloading refers to the ability to define same method name with different parameters in the same class.The method to be executed is determined by the types of arguments passed.
         Python does not support method overloading like other languages. If we define multiple methods with the same name but different parameters, only the most recent definition will be executed.

'''

# %%
'''
12. What is method overriding in OOP?
  -->Method Overriding in OOP is a concept where subclass provides own specfic implementation for a method that is defined in it's superclass. When the method is called on an object of subclass, the subclass method will be executed instead of super class method.

'''

# %%
'''
13. What is a property decorator in Python?
  -->The @property decorator is a built in python decorator that is used to define properties in a class.
      It provides a way to access to way to access instance attributes if they were public.
      Using getter and setter a private attributes can be accessed.

'''

# %%
'''
14.Why is polymorphism important in OOP?
  -->1.Flexibility and Extensibility:
        It allows to write a code that operates on objects of a base class and this code will automatically work with any subclass derived from it.

     2.Code Reusability:
        A single funcion or method can process objects of different types as long as they share a common interfac. This avoids rewriting redundant code for similar operation on different types.

     3.Simplified and Cleaner code:
        It reduces the need for lengthy statements like if-elif-else which differentiate between object types and perform type-specific actions.

     4.Decoupling:
        Polymorphism helps decouple the calling code from the specfic implementation of the objects it interacts with.

     5.Testability:
        It is easier to test individual component because you can mock or substitute objects that adhere to the same interface.

'''

# %%
'''
15.What is an abstract class in Python?
  --> An Abstract class in Python is a class that cannot be instantiated directly and the methods declared inside the class will have only method defination but not implementation.
      It's primary purpose is to serve as a blueprint for other subclasses.

'''

# %%
'''
16.What are the advantages of OOP?
  --> 1.Modularity:
          OOP provides breaking down complex problems into smaller, manageable and self-contained units.Each object has a clear responsibility, making the system easier to understand,design and maintain.

      2.Reusability:
          Through concept like Inheritance and composition code can be instantiated multiple times and it's functionalities can be extended by creating subclasses reducing rebundant code.

      3.Maintainability:
          The modulur nature of OOP makes it easier to debug and maintain code. Changes in one part of the system are less likely to affect other parts, as objects interact through well-defined interfaces.

      4.Extensibilty :
          New feature and functionalities can be added to existing system without significant altering the core code.
          Inheritance and Polymorphism allows to easily extension by creating new subclasses that inherit and extending existing behaviour.

      5.Data security:
          Encapsulation helps protect data from unintended modification by bundling data with the methods that operate on it and controlling access to internal state.

      6.Improved design and Abstraction:
          OOP encourages thinking about real-world entities and their interactions, leading to more intutive and understandable software designs.
          Abstraction helps manage complexity by hiding unnecessary details and presenting s simplified view.

      7.Polymorphism for flexibility
          Polymorphism allows object of different types to be treated uniformly, leading to more flexible and generic code.

      8.Easier collabration:
          With well-defined classes and interfaces, multiple developers can work on different parts of a large project concurrently, as long as they adhere to the agreed upon object interface.

      9.Problem solving closer to Real world:
          OOP allows mapping real-world ntities and their relaationships directly into software objects, making the development process more intutive.

'''

# %%
'''
17. What is the difference between a class variable and an instance variable?
  -->In Python, both class variable and instance variable are used to store data within class, but they differ in how they are defined, stored and accessed and critically in their scope and lifetime.

      Class variable:
        1.Defined directly within the class body, ouside any method
        2.Sharedby by all instance of that class.Shared by all instance of that class. There is only one copy of the class variable per class
        3.Accessed using Classname.variable_name or Instancename.variable_name.
        4.Store data that is common to all instances, or constants related to the class.
        5.Changing a class variable affects all instances.

      Instance variable:
        1.Defined inside the method typically(__init__) using self.
        2.Unique to each individual instance of the class, Each object has it's own copy.
        3.Accessed using instance_name.variable_name.
        4.Store data that is specific and unique to each object.
        5.Changing an instance variable only affects that specific instance.

'''

# %%
'''
18.What is multiple inheritance in Python?
  -->Multiple inheritance is an OOP feature where a class can inherit properties and behaviors from more than one parent (base) class. This means a child class can combine functionalities from multiple distinct sources.

'''

# %%
'''
19.Explain the purpose of __str__ and __repr__ methods in Python.
  -->__str__ and __repr__ are both "dunder" (double underscore) methods in Python that define how an object is represented as a string. They serve different purposes and are used in different contexts:

      __str__(self)
        Purpose: To provide a human-readable string representation of an object. It's intended for end-users and should be clear, concise, and informative.
        Invoked by:
          print(obj)
          str(obj)
          format()
          f-strings (when no specific format is given)
        Return Value: Must return a string.

      __repr__(self)
        Purpose: To provide an unambiguous string representation of an object. It's primarily intended for developers, debugging, and logging. The goal is that, if possible, eval(repr(obj)) should recreate the original object.
        Invoked by:
          repr(obj)
          logging.debug(obj)
        Return Value: Must return a string.

'''

# %%
'''
20.What is the significance of the super() function in Python?
  -->The super() function in Python is used to call a method or access an attribute from a parent (superclass) or sibling class in a class hierarchy, especially in the context of inheritance.

    Purpose:
      1.Calling Parent Constructor(__init__):
        This is the most common use case. In a subclass's __init__ method, super(). __init__ is used to ensure that the parent class's initialization logic is executed.

      2.Calling Overridden Methods:
        If a subclass overrides a method from it's parent class, super(), method_name() allows the subclass to still invoke the parent's version of that method, often to extend it's behaviour rather than completely replacing it.

      3.Cooperative Multiple Inheritance:
        In heritance scenerios super() plays a vital role in ensuring that methods in the Method Resolutiion Order are called correctly and cooperativley.It dynamically determines the next class in the MRO to call, ensuring that each methos in the hierarchy is called exactly once in the correct order.


'''

# %%
'''
21.What is the significance of the __del__ method in Python?
  --> The __del__ method(often called the destructor or finalizer) in Python is a special dunder method that is automatically called when an object is about to destroyed or garbage-collected.

  '''

# %%
'''
22.What is the difference between @staticmethod and @classmethod in Python?
  -->@classmethod:
      a.Takes cls(the class itself) as it's first arguement.
      b.Can access and modify class-level attributes and call other class methods.
      c.Commonly used for alternative constructor or operations that pertain to the class as a whole.

    @staticmethod:
      a.Takes no special first arguement(self or cls).
      b.Behaves like a regular function defined inside a class. It cannot access instance-specific data or class-specific data directly.
      c.Used for utility function that logically belongs to the class but don't require any class or instance state.

'''

# %%
'''
23.How does polymorphism work in Python with inheritance?
  -->Polymorphism in Python, especially with inheritance works primarly through duck typing and method overriding.When a subclass inherits from a superclass, it can provide it's own implementation for methods that are also defined in the superclass(method overriding).

    Mechanism:
      a.Common Interface:
        A base class defines a set of methods(the common interface).Subclass inherit these methods.

      b.Method Overriding:
        Subclasses can override these inherited methods, providing their own specific implementtation.

      c.Duck Typing:
        Python's dynamic typing system doesn't care about the explicit type of an object,only whether it "quackes like a duck".
        If multiple objects(from different classes in an inheritance hierarchy) have a method with the same name, they can all be used interchangeably, whereever that method is expected.

      d.Dynamic Dispatch:
        When a method is called on an obkect, Python determines at runtime(dynamically) which specific implementation of that method to execute based on the actual type of the object.


'''

# %%
'''
24.What is method chaining in Python OOP?
  --> Method Chaning(also known as "fluent interface") is a programming technique where multiple method calls are strung together on the same object in a single statement. This is possible when the chain returns objects itself(self), allowing the next method to be called directly on the result of the previous method.

'''

# %%
'''
25.What is the purpose of the __call__ method in Python?
  -->The __call__ method is a "dunder" method in Python that, when defined in a class, makes instances of that class callable like regular functions.

      Purpose:
        a.Creating callable objects(Functions):
            It allows to create objects that behave like functions. This can be useful when an object to maintain some interanl state across calls, or when you need an object that can be passedaround and executed like a function.

        b.Stateful Functions:
            Unlike pure functions callable objects can have attributes and methods allowing them to carry state between calls.

        c.Custom Decorator's:
            __call__ is often used in the implementation of class-based decorators

        d.Simulating closures:
            Can sometime be used as an alternative to closure for maintain state.

'''

# %% [markdown]
# PRACTICAL QUESTIONS

# %% [markdown]
# 1.Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".

# %%
class Animal:
   def speak(self):
      print("Generic animal sound")

class Dog(Animal):
  def speak(self):
    print("Bark!")

dog = Dog()
dog.speak()
# Out:
# Bark!

# %% [markdown]
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.

# %%
import math
class Shape:
  def area(*agrg):
    pass

class Rectangle(Shape):
  def area(self,length,width):
    return f"area of rectangle {length*width} sq.m"

class Circle(Shape):
  def area(self,radius):
    return f"area of circle {math.pi*radius**2} sq.m"

rectangle = Rectangle()
print(rectangle.area(5,10))

circle = Circle()
print(circle.area(4))
# Out:
# area of rectangle 50 sq.m
# area of circle 50.26548245743669 sq.m

# %% [markdown]
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.

# %%
class Vehicle:
  def __init__(self,type):
    self.type = type

  def properties(self):
    return self

class Car(Vehicle):
  def __init__(self,type,colour):
    super().__init__(type)
    self.colour = colour

  def properties(self):
    return self.colour

class ElectricCar(Car):
  def __init__(self,type,colour,battery):
    super().__init__(type,colour)
    self.battery = battery

  def properties(self):
    return self.battery

car = ElectricCar("X3","White","Exide")
car.properties()
# Out:
# 'Exide'

# %% [markdown]
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

# %%
class Bird:
  def fly(self):
    pass

class Sparrow(Bird):
  def fly(self):
    return "Sparrow can fly"

class Penguin(Bird):
  def fly(self):
    return "Penguin can not fly"

bird = Bird()
bird.fly()

sparrow = Sparrow()
sparrow.fly()

penguin = Penguin()
penguin.fly()
# Out:
# 'Penguin can not fly'

# %% [markdown]
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.

# %%
class BankAccount:
  def __init__(self, balance):
    self.__balance = balance

  def deposit(self, amount):
    return self.__balance += amount

  def withdraw(self, amount):
    if self.__balance >= amount:
      self.__balance -= amount
    else: "Insufficient balance"
# Out:
# 'Current balance: 1200'

# %% [markdown]
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().

# %%
class Instrument:
  def play(self):
    pass

class Guitar(Instrument):
  def play(self):
    return "Guitar is playing"

class Piano(Instrument):
  def play(self):
    return "Piano is playing"

guitar = Guitar()
guitar.play()

# %% [markdown]
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:

  @classmethod
  def add_numbers(cls,num1,num2):
    return num1+num2

  @staticmethod
  def subtract_numbers(num1,num2):
    return num1-num2

MathOperations.add_numbers(5,10)
MathOperations.subtract_numbers(5,10)
# Out:
# -5

# %% [markdown]
# 8. Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
  count = 0

  def __init__(self, name):
    self.name = name
    Person.count += 1

  @classmethod
  def person_created(cls):
    return f'Total number of persons created: {cls.count}'

person = Person("John")
print(person.person_created())

person2 = Person("Jane")
print(person2.person_created())
# Out:
# No.of Objects created: 1, Object name: John
# 'No.of Objects created: 2, Object name: Jane'

# %% [markdown]
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".

# %%
class Fraction:
  def __init__(self,numerator,denominator):
    self.numerator = numerator
    self.denominator = denominator

  def __str__(self):
    return f"{self.numerator}/{self.denominator}"

fraction = Fraction(5,10)
print(fraction)
# Out:
# 5/10

# %% [markdown]
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.

# %%
class Vector:
  def __init__(self, x, y):
    self.x = x
    self.y = y

  def __add__(self, other):
    if isinstance(other, Vector):
      return Vector(self.x + other.x, self.y + other.y)
    else:
      raise TypeError("Unsupported operand type for +")

  def __str__(self):
    return f"Vector({self.x}, {self.y})"

vector1 = Vector(2, 3)
vector2 = Vector(4, 5)

vector3 = vector1 + vector2

print(vector3)

# %% [markdown]
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."

# %%
class Person:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def greet(self):
    return f'Hello, my name is {self.name} and I am {self.age} years old'

person = Person("John",24)
person.greet()
# Out:
# 'Hello, my name is John and I am 24 years old'

# %% [markdown]
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.

# %%
class Students:

  def __init__(self, name, grades):
    self.name = name
    self.grades = grades

  def average_grade(self):
    return sum(self.grades)/len(self.grades)

student = Students("John",[50,60,70])
student.average_grade()
# Out:
# 60.0

# %% [markdown]
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.

# %%
class Rectangle:

  def set_demension(self,length,width):
    self.length = length
    self.width = width
    return area(self)

  def area(self):
    return self.length*self.width

rectangle = Rectangle()
rectangle.set_demension(5,10)
# Out:
# 50

# %% [markdown]
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
class Employee:
  def calculate_salary(self,hours_worked,hourly_rate):
    return hours_worked*hourly_rate

class Manager(Employee):
  def calculate_salary(self,hours_worked,hourly_rate,bonus):
    employee_salary = super().calculate_salary(hours_worked,hourly_rate)
    manager_salary = employee_salary + bonus
    return f'Manager salary {manager_salary}'

employee = Employee()
print(f'Employee salary {employee.calculate_salary(5,10)}')

manager = Manager()
print(manager.calculate_salary(5,10,500))
# Out:
# Employee salary 50
# Manager salary 550

# %% [markdown]
# 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product

# %%
class Product:
  def __init__(self,name,price,quantity):
    self.name = name
    self.price = price
    self.quantity = quantity

  def total_price(self):
    return f'Total Price for the product {self.name} is {self.price*self.quantity}'

product = Product("Apple",10,5)
product.total_price()
# Out:
# 'Total Price for the product Apple is 50'

# %% [markdown]
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
  @abstractmethod
  def sound(self):
    pass

class Cow(Animal):
  def sound(self):
    return "Moo"

class Sheep(Animal):
  def sound(self):
    return "Baa"

cow = Cow()
print(cow.sound())

sheep = Sheep()
print(sheep.sound())
# Out:
# Moo
# Baa

# %% [markdown]
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.

# %%
class Book:
  def __init__(self,title,author,year_published):
    self.title = title
    self.author = author
    self.year_published = year_published

  def __str__(self):
    return f'Title: {self.title}\nAuthor: {self.author}\nYear Published: {self.year_published}'

book = Book("The Alchemist","Paulo Coelho",1988)
print(book)
# Out:
# Title: The Alchemist
# Author: Paulo Coelho
# Year Published: 1988

# %% [markdown]
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.

# %%
class House:
  def __init__(self,address,price):
    self.address = address
    self.price = price

class Mansion(House):
  def __init__(self,address,price,number_of_rooms):
    self.number_of_rooms = number_of_rooms
    super().__init__(address,price)

house = House("123 Main St",100000)
print(house.address,house.price)

mansion = Mansion("123 Main St",100000,5)
print(mansion.address,mansion.price,mansion.number_of_rooms)
# Out:
# 123 Main St 100000
# 123 Main St 100000 5
